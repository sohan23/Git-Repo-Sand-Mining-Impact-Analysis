# %%
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl
import os

# %%
# Read in the Excel files
file1 = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\Bar Area\Excel Table\Mon-2016-R4_TableToExcel.xls')
file2 = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\Bar Area\Excel Table\Mon-2016-R5_TableToExcel.xls')
file3 = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\Bar Area\Excel Table\Mon-2016-R6_TableToExcel.xls')
# # Read in the Excel files
# file4 = pd.read_excel('file1.xls')
# file5 = pd.read_excel('file2.xls')
# file6 = pd.read_excel('file3.xls')
# # Read in the Excel files
# file7 = pd.read_excel('file1.xls')
# file8 = pd.read_excel('file2.xls')
# file9 = pd.read_excel('file3.xls')

# %%
# Extract the "Area" column from each file and sum it
area1 = file1['Area']
area1 = area1/1000000
# area2 = file2['Area'].sum()
# area3 = file3['Area'].sum()

# %%
# Create a bar plot of the sum of "Area" for each file
plt.bar(['File 1', 'File 2', 'File 3'], [area1, area2, area3])
plt.xlabel('Excel Files')
plt.ylabel('Sum of Area')
plt.title('Sum of Area for Three Specific Excel Files')

# Count the number of rows in each file
# rows1 = len(file1.index)
# rows2 = len(file2.index)
# rows3 = len(file3.index)

# Create a scatter plot of the number of rows in each file
plt.figure()
plt.scatter([rows1, rows2, rows3], [area1, area2, area3])
plt.xlabel('Number of Rows')
plt.ylabel('Sum of Area')
plt.title('Number of Rows vs Sum of Area for Three Specific Excel Files')

plt.show()

# %%
# Count the number of rows in each file
rows1 = len(file1.index)
rows2 = len(file2.index)
rows3 = len(file3.index)

# Create a bar plot of the sum of "Area" for each file
fig, ax1 = plt.subplots()
ax1.bar(['File 1', 'File 2', 'File 3'], [area1, area2, area3], color='b')
ax1.set_xlabel('Excel Files')
ax1.set_ylabel('Sum of Area', color='b')
ax1.tick_params('y', colors='b')

# Create a scatter plot of the number of rows in each file on the same figure
ax2 = ax1.twinx()
ax2.scatter(['File 1', 'File 2', 'File 3'], [rows1, rows2, rows3], color='r')
ax2.set_ylabel('Number of Rows', color='r')
ax2.tick_params('y', colors='r')

plt.title('Sum of Area and Number of Rows for Three Specific Excel Files')

# Show the plot
plt.show()

# %%
plt.bar(area1,height=area1, width=0.5, bottom=None, align='center', data=None, color='b')
plt.show()
