# %% [markdown]
# # RivWidth Calculation with python

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import openpyxl
from scipy.interpolate import splrep, splev
# %matplotlib inline

# %% [markdown]
# ## Defining the Input folder

# %%
input_folder = 'F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\River Width'

# %%
#Read the excel data
df = pd.read_excel(os.path.join(input_folder, 'RivWidth-1965.xls'))
df = df.iloc[2:]
df
# Out:
#      FID   Id      Length Range
# 2    NaN  NaN    0.000000     1
# 3    NaN  NaN    0.000000     2
# 4    NaN  NaN    0.000000     3
# 5    2.0  0.0   78.580701     4
# 6   10.0  0.0   48.721511     4
# 7    3.0  0.0   89.650753     5
# 8    8.0  0.0  125.496203     5
# 9    4.0  0.0  125.465739     6
# 10   5.0  0.0  108.099140     7
# 11   6.0  0.0   89.404306     8
# 12   7.0  0.0  148.804373     9
# 13   9.0  0.0  105.063209     9

# %%
# Create a new column 'marker' to control the marker style of each point in the scatter plot
df['marker'] = df.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df['marker'].unique():
    plt.scatter(df.loc[df['marker'] == marker, 'Range'],
                df.loc[df['marker'] == marker, 'Length'], marker=marker,s=36)

# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-1965')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

# %% [markdown]
# #### For Pre-2017

# %%
# Read the excel data
df1 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Pre-2017.xls'))
df1 = df1.iloc[1:]
df1
# Out:
#     FID  Id      Length  Range
# 1     1   0  115.108715    1.0
# 2     2   0   31.783548    2.0
# 3     3   0  120.258003    3.0
# 4     4   0   35.369294    4.0
# 5     5   0   54.836312    4.0
# 6     6   0   33.609981    5.0
# 7     7   0   19.421125    5.0
# 8     8   0   86.980577    6.0
# 9     9   0  130.077875    7.0
# 10   10   0   74.953414    8.0
# 11   11   0   71.880209    9.0

# %%
# Create a new column 'marker' to control the marker style of each point in the line plot
df1['marker'] = df1.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a line plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df1['marker'].unique():
    plt.scatter(df1.loc[df1['marker'] == marker, 'Range'],
             df1.loc[df1['marker'] == marker, 'Length'], marker=marker,s=36)

# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Pre-2017')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='lower right')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

# %% [markdown]
# #### For Pre 2018

# %%
# Read the excel data
df2 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Pre-2018.xls'))
df2 = df2.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df2['marker'] = df2.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df2['marker'].unique():
    plt.scatter(df2.loc[df2['marker'] == marker, 'Range'],
                df2.loc[df2['marker'] == marker, 'Length'], marker=marker,s=36)

# Show the plot
# plt.plot(df2['Range'], df2['Length'], 'o', color='blue')
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Pre-2018')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

# %% [markdown]
# #### For Pre 2019 and 2020

# %%
df3 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Pre-2019.xls'))
df3 = df3.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df3['marker'] = df3.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df3['marker'].unique():
    plt.scatter(df3.loc[df3['marker'] == marker, 'Range'],
                df3.loc[df3['marker'] == marker, 'Length'], marker=marker,s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Pre-2019')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df4 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Pre-2020.xls'))
df4 = df4.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df4['marker'] = df4.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df4['marker'].unique():
    plt.scatter(df4.loc[df4['marker'] == marker, 'Range'],
                df4.loc[df4['marker'] == marker, 'Length'], marker=marker,s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Pre-2020')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

# %% [markdown]
# #### For Monsoon

# %%
df5 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Mon-2016.xls'))
df5 = df5.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df5['marker'] = df5.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df5['marker'].unique():
    plt.scatter(df5.loc[df5['marker'] == marker, 'Range'],
                df5.loc[df5['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Mon-2016')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df6 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Mon-2017.xls'))
df6 = df6.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df6['marker'] = df6.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df6['marker'].unique():
    plt.scatter(df6.loc[df6['marker'] == marker, 'Range'],
                df6.loc[df6['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Mon-2017')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df7 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Mon-2018.xls'))
df7 = df7.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df7['marker'] = df7.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df7['marker'].unique():
    plt.scatter(df7.loc[df7['marker'] == marker, 'Range'],
                df7.loc[df7['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Mon-2018')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df8 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Mon-2019.xls'))
df8 = df8.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df8['marker'] = df8.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df8['marker'].unique():
    plt.scatter(df8.loc[df8['marker'] == marker, 'Range'],
                df8.loc[df8['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Mon-2019')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df9 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Mon-2020.xls'))
df9 = df9.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df9['marker'] = df9.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df9['marker'].unique():
    plt.scatter(df9.loc[df9['marker'] == marker, 'Range'],
                df9.loc[df9['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Mon-2020')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

# %% [markdown]
# #### For PostMonsoon

# %%
df10 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Post-2016.xls'))
df10 = df10.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df10['marker'] = df10.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df10['marker'].unique():
    plt.scatter(df10.loc[df10['marker'] == marker, 'Range'],
                df10.loc[df10['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Post-2016')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df11 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Post-2017.xls'))
df11 = df11.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df11['marker'] = df11.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df11['marker'].unique():
    plt.scatter(df11.loc[df11['marker'] == marker, 'Range'],
                df11.loc[df11['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Post-2017')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df12 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Post-2018.xls'))
df12 = df12.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df12['marker'] = df12.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df12['marker'].unique():
    plt.scatter(df12.loc[df12['marker'] == marker, 'Range'],
                df12.loc[df12['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Post-2018')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df13 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Post-2019.xls'))
df13 = df13.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df13['marker'] = df13.groupby('Range')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df13['marker'].unique():
    plt.scatter(df13.loc[df13['marker'] == marker, 'Range'],
                df13.loc[df13['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Post-2019')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()

df14 = pd.read_excel(os.path.join(input_folder, 'RivWidth-Post-2020.xls'))
# df14 = df14.iloc[1:]

#Create a new column 'marker' to control the marker style of each point in the scatter plot
df14['marker'] = df14.groupby('Reach')['Length'].transform(
    lambda x: ['o' if i == 1 else '^' for i in x.rank(ascending=False)])

# Create a scatter plot with x as Range and y as Length, where the marker value controls the marker style of each point
for marker in df14['marker'].unique():
    plt.scatter(df14.loc[df14['marker'] == marker, 'Reach'],
                df14.loc[df14['marker'] == marker, 'Length'], marker=marker, s=36)
    
# Show the plot
plt.xlabel('Reach')
plt.ylabel('Length (m)')
plt.title('River Width-Post-2020')
plt.legend(['Primary Channel', 'Secondary Channel'], loc='best')
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()
