# %%
import numpy as np
import pandas as pd
import os
import openpyxl
# import matplotlib as mpl
import matplotlib.pyplot as plt
# import matplotlib.ticker as tck
# %matplotlib inline

# %%
input_folder ="F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Meandering Index\Plots"

# %%
folder_files = os.listdir(input_folder)
print("This Folder contains {} file(s).".format(len(folder_files)))
for file in folder_files:
    print(file)
# Out:
# This Folder contains 13 file(s).
# Meander-2016.svg
# Meander-2017.svg
# Meander-2018.svg
# Meander-2019.svg
# Meander-2020.svg
# Meander-Monsoon.svg
# Meander-Post-monsoon.svg
# Meander-Pre-monsoon.svg
# Meandering Python Script.ipynb
# Meandering-Final-1.xlsx
# Meandering-Final-Updated.csv
# Meandering-Final.csv
# plot.ipynb

# %%
df2 = pd.read_csv('Meandering-Final-Updated.csv')
df2
# Out:
#    Reach      1965  Mon-2016  Mon-2017  Mon-2018  Mon-2019  Mon-2020  \
# 0      1  1.211051  1.366766  1.290761  1.276657  1.289467  1.269982
# 1      2  0.000000  1.181659  1.250250  1.168382  1.259454  1.204144
# 2      3  0.000000  1.302945  1.145420  1.232438  1.134474  1.198124
# 3      4  0.813785  1.173761  1.106044  1.133517  1.140422  1.157064
# 4      5  1.190774  1.423745  1.170305  1.147476  1.128904  1.282625
# 5      6  1.689567  1.500634  1.583765  1.536755  1.603840  1.229351
# 6      7  1.220487  1.793857  1.853307  1.705301  1.798702  1.957869
# 7      8  1.259128  1.229359  1.200877  1.197142  1.266250  1.416461
# 8      9  0.324727  0.996554  0.978619  0.848348  0.889450  0.932746
#
#    Post-2016  Post-2017  Post-2018  Post-2019  Post-2020  Pre-2017  Pre-2018  \
# 0   1.308169   1.251769   1.361674   1.288494   0.714215  1.328686  1.380284
# 1   1.089575   1.118899   1.271264   1.167559   1.161430  1.229276  1.209527
# 2   1.129832   1.060676   1.215627   1.159241   1.106244  1.354167  1.192247
# 3   1.214168   1.039301   1.090357   1.063215   1.080648  1.478536  1.152040
# 4   1.212928   1.280335   1.438098   1.132046   1.053275  1.430762  1.293268
# 5   1.530831   1.418296   1.339053   1.829584   1.267186  1.572573  1.677873
# 6   1.752337   1.655472   1.921725   1.201525   1.707955  1.709857  1.840921
# 7   1.251240   1.209747   1.236933   1.328075   1.248982  1.255634  1.282127
# 8   0.928869   0.834118   0.944081   0.863881   0.814563  0.969255  1.063429
#
#    Pre-2019  Pre-2020
# 0  1.285456  0.723359
# 1  1.208813  1.204958
# 2  1.128877  1.226638
# 3  1.126167  1.185258
# 4  1.210549  1.307564
# 5  1.541131  1.527003
# 6  1.625754  2.022158
# 7  1.302722  1.327120
# 8  0.926707  0.957901

# %%
# For the year 1965 vs 2019
# 1965
plt.plot(df2["Reach"], df2['1965'], marker='s', markerfacecolor='black',
         markersize=5, color='black', linewidth=2, label='1965')

# Pre-Monsoon 2019
plt.plot(df2["Reach"], df2['Pre-2019'], marker='o', markerfacecolor='black',
         markersize=5, color='red', linewidth=2, label='Pre-2019')

# Monsoon 2019
plt.plot(df2["Reach"], df2['Mon-2019'], marker='^', markerfacecolor='black',
         markersize=5, color='magenta', linewidth=2, label='Mon-2019')

# Post-Monsoon 2019
plt.plot(df2["Reach"], df2['Post-2019'], marker='*', markerfacecolor='black',
         markersize=5, color='green', linewidth=2, label='Post-2019')

# Axis and Titles
plt.title("Meandering Index for the year 2019")
plt.xlabel("Reach")
plt.ylabel("Meandering Index")
plt.legend()
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.show()
