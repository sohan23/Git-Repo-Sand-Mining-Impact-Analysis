# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import openpyxl

# %%
input_path = 'F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameteers'

# %%
# Load the Excel file
df = pd.read_excel('Production Report Yamunanagar Sites.xlsx',sheet_name='Final_Sheet')
df
# Out:
#          Time  Total Production
# 0    Mon-2016            135484
# 1   Post-2016            255080
# 2    Pre-2017            731342
# 3    Mon-2017            951484
# 4   Post-2017           1975899
# 5    Pre-2018           2749370
# 6    Mon-2018           1194628
# 7   Post-2018           2173888
# 8    Pre-2019           1437621
# 9    Mon-2019           1628867
# 10  Post-2019           1791025
# 11   Pre-2020            793007
# 12   Mon-2020           1605394
# 13  Post-2020            748648

# %%
df.plot.bar(x='Time',y='Total Production',color='orange')
plt.xlabel('Time')
plt.ylabel('Total Production in Tonnes')
plt.title('Total Production in Tonnes vs Seasonal Variability throughout the years',fontdict={'fontname': 'Times New Roman', 'fontsize': 18})
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)

plt.show()
