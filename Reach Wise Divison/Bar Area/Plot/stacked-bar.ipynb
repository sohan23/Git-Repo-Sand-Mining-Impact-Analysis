# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import openpyxl

print = os.getcwd()

# Read the excel file
df = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\BAvsWA\concatenated_file-Plotting.xlsx')

# Plot the 1965 Exposed Bar vs Water Area
x = df.iloc[:, 0]
A = df['Pre-2017-Exposed-Bar']
B = df['Mon-2017-Exposed-Bar']
C = df['Post-2017-Exposed-Bar']

bar_width = 0.18
x1 = np.arange(len(x))
x2 = [i + bar_width for i in x1]
x3 = [i + bar_width for i in x2]

plt.figure(figsize=(16, 10))  # increase figure size
plt.bar(x1, A, width=bar_width, label='Pre-2017-Exposed-Bar')
plt.bar(x2, B, width=bar_width, label='Mon-2017-Exposed-Bar')
plt.bar(x3, C, width=bar_width, label='Post-2017-Exposed-Bar')

# Add vertical text annotations with values rounded to 3 decimal points and increased spacing
for i in range(len(A)):
    plt.text(x=x1[i]-0.05, y=A[i]+0.01, s=f"{A[i]:.3f}", size=9, rotation=90)
    plt.text(x=x2[i]-0.05, y=B[i]+0.01, s=f"{B[i]:.3f}", size=9, rotation=90)
    plt.text(x=x3[i]-0.05, y=C[i]+0.01, s=f"{C[i]:.3f}", size=9, rotation=90)

plt.xticks([i + bar_width for i in range(len(x))], x)
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.xlabel('Reach')
plt.ylabel('Exposed Bar ')
plt.title('2017 Variability in Exposed Bar Area', fontweight='bold',fontdict={'fontname':'Times New Roman'}, fontsize=18)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import openpyxl

print = os.getcwd()

# Read the excel file
df = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\BAvsWA\concatenated_file-Plotting.xlsx')

# Plot the 1965 Exposed Bar vs Water Area
x = df.iloc[:, 0]
A = df['Pre-2018-Exposed-Bar']
B = df['Mon-2018-Exposed-Bar']
C = df['Post-2018-Exposed-Bar']

bar_width = 0.18
x1 = np.arange(len(x))
x2 = [i + bar_width for i in x1]
x3 = [i + bar_width for i in x2]

plt.figure(figsize=(16, 10))  # increase figure size
plt.bar(x1, A, width=bar_width, label='Pre-2018-Exposed-Bar')
plt.bar(x2, B, width=bar_width, label='Mon-2018-Exposed-Bar')
plt.bar(x3, C, width=bar_width, label='Post-2018-Exposed-Bar')

# Add vertical text annotations with values rounded to 3 decimal points and increased spacing
for i in range(len(A)):
    plt.text(x=x1[i]-0.05, y=A[i]+0.01, s=f"{A[i]:.3f}", size=9, rotation=90)
    plt.text(x=x2[i]-0.05, y=B[i]+0.01, s=f"{B[i]:.3f}", size=9, rotation=90)
    plt.text(x=x3[i]-0.05, y=C[i]+0.01, s=f"{C[i]:.3f}", size=9, rotation=90)

plt.xticks([i + bar_width for i in range(len(x))], x)
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.xlabel('Reach')
plt.ylabel('Exposed Bar')
plt.title('2018 Variability in Exposed Bar Area', fontweight='bold',
          fontdict={'fontname': 'Times New Roman'}, fontsize=18)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 10
#       7 print = os.getcwd()
#       9 # Read the excel file
# ---> 10 df = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\BAvsWA\concatenated_file-Plotting.xlsx')
#      12 # Plot the 1965 Exposed Bar vs Water Area
#      13 x = df.iloc[:, 0]
#
# File c:\Users\SOHAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\SOHAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\SOHAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File c:\Users\SOHAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File c:\Users\SOHAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File c:\Users\SOHAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'F:\\One Drive\\OneDrive - Indian Institute of Science Education and Research Bhopal\\Excel data for Various Parameters\\Reach Wise Divison\\BAvsWA\\concatenated_file-Plotting.xlsx'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import openpyxl

print = os.getcwd()

# Read the excel file
df = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\BAvsWA\concatenated_file-Plotting.xlsx')

# Plot the 1965 Exposed Bar vs Water Area
x = df.iloc[:, 0]
A = df['Pre-2019-Exposed-Bar']
B = df['Mon-2019-Exposed-Bar']
C = df['Post-2019-Exposed-Bar']

bar_width = 0.18
x1 = np.arange(len(x))
x2 = [i + bar_width for i in x1]
x3 = [i + bar_width for i in x2]

plt.figure(figsize=(16, 10))  # increase figure size
plt.bar(x1, A, width=bar_width, label='Pre-2019-Exposed-Bar')
plt.bar(x2, B, width=bar_width, label='Mon-2019-Exposed-Bar')
plt.bar(x3, C, width=bar_width, label='Post-2019-Exposed-Bar')

# Add vertical text annotations with values rounded to 3 decimal points and increased spacing
for i in range(len(A)):
    plt.text(x=x1[i]-0.05, y=A[i]+0.01, s=f"{A[i]:.3f}", size=9, rotation=90)
    plt.text(x=x2[i]-0.05, y=B[i]+0.01, s=f"{B[i]:.3f}", size=9, rotation=90)
    plt.text(x=x3[i]-0.05, y=C[i]+0.01, s=f"{C[i]:.3f}", size=9, rotation=90)

plt.xticks([i + bar_width for i in range(len(x))], x)
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.xlabel('Reach')
plt.ylabel('Exposed Bar')
plt.title('2019 Variability in Exposed Bar Area', fontweight='bold',
          fontdict={'fontname': 'Times New Roman'}, fontsize=18)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import openpyxl

print = os.getcwd()

# Read the excel file
df = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\BAvsWA\concatenated_file-Plotting.xlsx')

# Plot the 1965 Exposed Bar vs Water Area
x = df.iloc[:, 0]
A = df['Pre-2020-Exposed-Bar']
B = df['Mon-2020-Exposed-Bar']
C = df['Post-2020-Exposed-Bar']

bar_width = 0.18
x1 = np.arange(len(x))
x2 = [i + bar_width for i in x1]
x3 = [i + bar_width for i in x2]

plt.figure(figsize=(16, 10))  # increase figure size
plt.bar(x1, A, width=bar_width, label='Pre-2020-Exposed-Bar')
plt.bar(x2, B, width=bar_width, label='Mon-2020-Exposed-Bar')
plt.bar(x3, C, width=bar_width, label='Post-2020-Exposed-Bar')

# Add vertical text annotations with values rounded to 3 decimal points and increased spacing
for i in range(len(A)):
    plt.text(x=x1[i]-0.05, y=A[i]+0.01, s=f"{A[i]:.3f}", size=9, rotation=90)
    plt.text(x=x2[i]-0.05, y=B[i]+0.01, s=f"{B[i]:.3f}", size=9, rotation=90)
    plt.text(x=x3[i]-0.05, y=C[i]+0.01, s=f"{C[i]:.3f}", size=9, rotation=90)

plt.xticks([i + bar_width for i in range(len(x))], x)
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.xlabel('Reach')
plt.ylabel('Exposed Bar')
plt.title('2020 Variability in Exposed Bar Area', fontweight='bold',
          fontdict={'fontname': 'Times New Roman'}, fontsize=18)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import openpyxl

print = os.getcwd()

# Read the excel file
df = pd.read_excel('F:\One Drive\OneDrive - Indian Institute of Science Education and Research Bhopal\Excel data for Various Parameters\Reach Wise Divison\BAvsWA\concatenated_file-Plotting.xlsx')

# Plot the 1965 Exposed Bar vs Water Area
x = df.iloc[:, 0]
# A = df['Pre-2016-Exposed-Bar']
B = df['Mon-2016-Exposed-Bar']
C = df['Post-2016-Exposed-Bar']

bar_width = 0.18
x1 = np.arange(len(x))
x2 = [i + bar_width for i in x1]
x3 = [i + bar_width for i in x2]

plt.figure(figsize=(16, 10))  # increase figure size
# plt.bar(x1, A, width=bar_width, label='Pre-2016-Exposed-Bar')
plt.bar(x2, B, width=bar_width, label='Mon-2016-Exposed-Bar')
plt.bar(x3, C, width=bar_width, label='Post-2016-Exposed-Bar')

# Add vertical text annotations with values rounded to 3 decimal points and increased spacing
for i in range(len(A)):
    # plt.text(x=x1[i]-0.05, y=A[i]+0.02, s=f"{A[i]:.3f}", size=9, rotation=90)
    plt.text(x=x2[i]-0.05, y=B[i]+0.02, s=f"{B[i]:.3f}", size=9, rotation=90)
    plt.text(x=x3[i]-0.05, y=C[i]+0.02, s=f"{C[i]:.3f}", size=9, rotation=90)

plt.xticks([i + bar_width for i in range(len(x))], x)
plt.grid(True, color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.xlabel('Reach')
plt.ylabel('Exposed Bar')
plt.title('2016 Variability in Exposed Bar Area', fontweight='bold',
          fontdict={'fontname': 'Times New Roman'}, fontsize=18)
plt.legend()
plt.show()
